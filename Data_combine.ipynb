# %%
import pandas as pd

# %%
data_hr1 = pd.read_csv('data/employee_survey_data.csv')

# %%
data_hr1 = data_hr1.drop(["YearsAtCompany"], axis=1)

# %%
data_hr1
# Out:
#       EmployeeID  EnvironmentSatisfaction  JobSatisfaction  WorkLifeBalance
# 0              1                      3.0              4.0              2.0
# 1              2                      3.0              2.0              4.0
# 2              3                      2.0              2.0              1.0
# 3              4                      4.0              4.0              3.0
# 4              5                      4.0              1.0              3.0
# ...          ...                      ...              ...              ...
# 4405        4406                      4.0              1.0              3.0
# 4406        4407                      4.0              4.0              3.0
# 4407        4408                      1.0              3.0              3.0
# 4408        4409                      4.0              1.0              3.0
# 4409        4410                      1.0              3.0              NaN
#
# [4410 rows x 4 columns]

# %%
data_hr2 = pd.read_csv('data/general_data.csv')

# %%
data_hr2
# Out:
#       Age Attrition     BusinessTravel              Department  \
# 0      51        No      Travel_Rarely                   Sales
# 1      31       Yes  Travel_Frequently  Research & Development
# 2      32        No  Travel_Frequently  Research & Development
# 3      38        No         Non-Travel  Research & Development
# 4      32        No      Travel_Rarely  Research & Development
# ...   ...       ...                ...                     ...
# 4405   42        No      Travel_Rarely  Research & Development
# 4406   29        No      Travel_Rarely  Research & Development
# 4407   25        No      Travel_Rarely  Research & Development
# 4408   42        No      Travel_Rarely                   Sales
# 4409   40        No      Travel_Rarely  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 0                    6          2  Life Sciences              1           1
# ...

# %%
data_hr4 = pd.merge(data_hr1, data_hr2, on=['EmployeeID'])

# %%
data_hr4
# Out:
#       EmployeeID  EnvironmentSatisfaction  JobSatisfaction  WorkLifeBalance  \
# 0              1                      3.0              4.0              2.0
# 1              2                      3.0              2.0              4.0
# 2              3                      2.0              2.0              1.0
# 3              4                      4.0              4.0              3.0
# 4              5                      4.0              1.0              3.0
# ...          ...                      ...              ...              ...
# 4405        4406                      4.0              1.0              3.0
# 4406        4407                      4.0              4.0              3.0
# 4407        4408                      1.0              3.0              3.0
# 4408        4409                      4.0              1.0              3.0
# 4409        4410                      1.0              3.0              NaN
#
# ...

# %%
data_hr3 = pd.read_csv('data/manager_survey_data.csv')

# %%
data_hr3
# Out:
#       EmployeeID  JobInvolvement  PerformanceRating
# 0              1               3                  3
# 1              2               2                  4
# 2              3               3                  3
# 3              4               2                  3
# 4              5               3                  3
# ...          ...             ...                ...
# 4405        4406               3                  3
# 4406        4407               2                  3
# 4407        4408               3                  4
# 4408        4409               2                  3
# 4409        4410               4                  3
#
# [4410 rows x 3 columns]

# %%
data_hr5 = pd.merge(data_hr4, data_hr3, on=['EmployeeID'])

# %%
data_hr5
# Out:
#       EmployeeID  EnvironmentSatisfaction  JobSatisfaction  WorkLifeBalance  \
# 0              1                      3.0              4.0              2.0
# 1              2                      3.0              2.0              4.0
# 2              3                      2.0              2.0              1.0
# 3              4                      4.0              4.0              3.0
# 4              5                      4.0              1.0              3.0
# ...          ...                      ...              ...              ...
# 4405        4406                      4.0              1.0              3.0
# 4406        4407                      4.0              4.0              3.0
# 4407        4408                      1.0              3.0              3.0
# 4408        4409                      4.0              1.0              3.0
# 4409        4410                      1.0              3.0              NaN
#
# ...

# %%
data_hr5 = data_hr5.drop(["EmployeeID"], axis=1)

# %%
data_hr5.columns
# Out:
# Index(['EnvironmentSatisfaction', 'JobSatisfaction', 'WorkLifeBalance', 'Age',
#        'Attrition', 'BusinessTravel', 'Department', 'DistanceFromHome',
#        'Education', 'EducationField', 'EmployeeCount', 'Gender', 'JobLevel',
#        'JobRole', 'MaritalStatus', 'MonthlyIncome', 'NumCompaniesWorked',
#        'Over18', 'PercentSalaryHike', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'YearsAtCompany',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager', 'JobInvolvement',
#        'PerformanceRating'],
#       dtype='object')

# %%
data_hr5
# Out:
#       EnvironmentSatisfaction  JobSatisfaction  WorkLifeBalance  Age  \
# 0                         3.0              4.0              2.0   51
# 1                         3.0              2.0              4.0   31
# 2                         2.0              2.0              1.0   32
# 3                         4.0              4.0              3.0   38
# 4                         4.0              1.0              3.0   32
# ...                       ...              ...              ...  ...
# 4405                      4.0              1.0              3.0   42
# 4406                      4.0              4.0              3.0   29
# 4407                      1.0              3.0              3.0   25
# 4408                      4.0              1.0              3.0   42
# 4409                      1.0              3.0              NaN   40
#
#      Attrition     BusinessTravel              Department  DistanceFromHome  \
# ...

# %%
data_hr5 = data_hr5.reindex(sorted(data_hr5.columns), axis=1)

# %%
data_hr5
# Out:
#       Age Attrition     BusinessTravel              Department  \
# 0      51        No      Travel_Rarely                   Sales
# 1      31       Yes  Travel_Frequently  Research & Development
# 2      32        No  Travel_Frequently  Research & Development
# 3      38        No         Non-Travel  Research & Development
# 4      32        No      Travel_Rarely  Research & Development
# ...   ...       ...                ...                     ...
# 4405   42        No      Travel_Rarely  Research & Development
# 4406   29        No      Travel_Rarely  Research & Development
# 4407   25        No      Travel_Rarely  Research & Development
# 4408   42        No      Travel_Rarely                   Sales
# 4409   40        No      Travel_Rarely  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 0                    6          2  Life Sciences              1
# 1                   10          1  Life Sciences              1
# ...

# %%
data_IBM = pd.read_csv('data/WA_Fn-UseC_-HR-Employee-Attrition.csv')

# %%
data_IBM
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
data_IBM = data_IBM.drop(["DailyRate", "HourlyRate", "MonthlyRate", "OverTime", "YearsInCurrentRole", "RelationshipSatisfaction", "EmployeeNumber"], axis=1)

# %%
data_IBM
# Out:
#       Age Attrition     BusinessTravel              Department  \
# 0      41       Yes      Travel_Rarely                   Sales
# 1      49        No  Travel_Frequently  Research & Development
# 2      37       Yes      Travel_Rarely  Research & Development
# 3      33        No  Travel_Frequently  Research & Development
# 4      27        No      Travel_Rarely  Research & Development
# ...   ...       ...                ...                     ...
# 1465   36        No  Travel_Frequently  Research & Development
# 1466   39        No      Travel_Rarely  Research & Development
# 1467   27        No      Travel_Rarely  Research & Development
# 1468   49        No  Travel_Frequently                   Sales
# 1469   34        No      Travel_Rarely  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 0                    1          2  Life Sciences              1
# 1                    8          1  Life Sciences              1
# ...

# %%
data_IBM = data_IBM.reindex(sorted(data_IBM.columns), axis=1)

# %%
data_IBM
# Out:
#       Age Attrition     BusinessTravel              Department  \
# 0      41       Yes      Travel_Rarely                   Sales
# 1      49        No  Travel_Frequently  Research & Development
# 2      37       Yes      Travel_Rarely  Research & Development
# 3      33        No  Travel_Frequently  Research & Development
# 4      27        No      Travel_Rarely  Research & Development
# ...   ...       ...                ...                     ...
# 1465   36        No  Travel_Frequently  Research & Development
# 1466   39        No      Travel_Rarely  Research & Development
# 1467   27        No      Travel_Rarely  Research & Development
# 1468   49        No  Travel_Frequently                   Sales
# 1469   34        No      Travel_Rarely  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 0                    1          2  Life Sciences              1
# 1                    8          1  Life Sciences              1
# ...

# %%
data_final = pd.concat([data_hr5, data_IBM], ignore_index=True)

# %%
data_final
# Out:
#       Age Attrition     BusinessTravel              Department  \
# 0      51        No      Travel_Rarely                   Sales
# 1      31       Yes  Travel_Frequently  Research & Development
# 2      32        No  Travel_Frequently  Research & Development
# 3      38        No         Non-Travel  Research & Development
# 4      32        No      Travel_Rarely  Research & Development
# ...   ...       ...                ...                     ...
# 5875   36        No  Travel_Frequently  Research & Development
# 5876   39        No      Travel_Rarely  Research & Development
# 5877   27        No      Travel_Rarely  Research & Development
# 5878   49        No  Travel_Frequently                   Sales
# 5879   34        No      Travel_Rarely  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 0                    6          2  Life Sciences              1
# 1                   10          1  Life Sciences              1
# ...

# %%
#data_final.to_csv("Employee_Years.csv",index=False)

# %%
age_groups = [0, 10, 20, 30, 40, 50, 60, 70, 100]

age_group_names = ['<10', '10-20', '21-30', '31-40', '41-50', '51-60', '61-70', '>70']

# %%
data_final['Age_group'] = pd.cut(data_final['Age'], bins=age_groups, labels=age_group_names)

# %%
data_final
# Out:
#       Age Attrition     BusinessTravel              Department  \
# 0      51        No      Travel_Rarely                   Sales
# 1      31       Yes  Travel_Frequently  Research & Development
# 2      32        No  Travel_Frequently  Research & Development
# 3      38        No         Non-Travel  Research & Development
# 4      32        No      Travel_Rarely  Research & Development
# ...   ...       ...                ...                     ...
# 5875   36        No  Travel_Frequently  Research & Development
# 5876   39        No      Travel_Rarely  Research & Development
# 5877   27        No      Travel_Rarely  Research & Development
# 5878   49        No  Travel_Frequently                   Sales
# 5879   34        No      Travel_Rarely  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 0                    6          2  Life Sciences              1
# 1                   10          1  Life Sciences              1
# ...

# %%
data_final.to_csv("Employee_Years.csv",index=False)
